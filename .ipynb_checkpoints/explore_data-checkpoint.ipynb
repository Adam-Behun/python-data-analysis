# %% [markdown]
# # Combining datasets

# %%
import pandas as pd

# %%
left = pd.DataFrame({'col1' : [1,2,3,4,5], 'col2' : ['a', 'b', 'c', 'd', 'e']})
right = pd.DataFrame({'col1' : [3,4,5,6,7], 'col3' : ['f', 'g', 'h', 'i', 'j']})

print(left)
print(right)
# Out:
#    col1 col2
# 0     1    a
# 1     2    b
# 2     3    c
# 3     4    d
# 4     5    e
#    col1 col3
# 0     3    f
# 1     4    g
# 2     5    h
# 3     6    i
# 4     7    j

# %% [markdown]
# # merge the two dataframes

# %%
pd.merge(left=left, right=right, on='col1')
# Out:
#    col1 col2 col3
# 0     3    c    f
# 1     4    d    g
# 2     5    e    h

# %%
pd.merge(left, right, on='col1', how='left')
# Out:
#    col1 col2 col3
# 0     1    a  NaN
# 1     2    b  NaN
# 2     3    c    f
# 3     4    d    g
# 4     5    e    h

# %%
pd.merge(left, right, on='col1', how='right')
# Out:
#    col1 col2 col3
# 0     3    c    f
# 1     4    d    g
# 2     5    e    h
# 3     6  NaN    i
# 4     7  NaN    j

# %%
# df1 is a pandas DataFrame
# df1 gets passed a dictionary of keys and values
df1 = pd.DataFrame({'account_id' : [1, 2, 3, 11382],       # account_id as the key and list of ints as values
                   'gender' : ['female', 'male', 'female', 'male'], 
                   'age' : [55, 25, 29, 39]})
df1
# Out:
#    account_id  gender  age
# 0           1  female   55
# 1           2    male   25
# 2           3  female   29
# 3       11382    male   39

# %%
df2 = pd.DataFrame({'account_id' : [4, 5, 6, 7],       # account_id as the key and list of ints as values
                   'gender' : ['female', 'male', 'female', 'male'], 
                   'age' : [19, 28, 14, 15]})
df2
# Out:
#    account_id  gender  age
# 0           4  female   19
# 1           5    male   28
# 2           6  female   14
# 3           7    male   15

# %%
pd.concat([df1, df2], ignore_index=True)
# Out:
#    account_id  gender  age
# 0           1  female   55
# 1           2    male   25
# 2           3  female   29
# 3       11382    male   39
# 4           4  female   19
# 5           5    male   28
# 6           6  female   14
# 7           7    male   15

# %%
hero_powers=pd.read_pickle('hero_powers.pkl')
hero_dc=pd.read_pickle('hero_dc.pkl')
hero_marvel=pd.read_pickle('hero_marvel.pkl')

# %%
hero_marvel.head(1)
# Out:
#      name Gender Eye color   Race Hair color  Height      Publisher Alignment  \
# 0  A-Bomb   Male    yellow  Human    No Hair     203  Marvel Comics      good
#
#    Weight
# 0     441

# %%
hero_dc.head(1)
# Out:
#        name Gender Eye color     Race Hair color  Height  Publisher Alignment  \
# 0  Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics      good
#
#    Weight
# 0    90.0

# %%
# shows how many rows and columns I have
hero_dc.shape
# Out:
# (215, 9)

# %%
hero_marvel.shape
# Out:
# (388, 9)

# %%
215+388
# Out:
# 603

# %%
hero_info=pd.concat([hero_dc, hero_marvel], ignore_index=True)

# %%
hero_info.head(1)
# Out:
#        name Gender Eye color     Race Hair color  Height  Publisher Alignment  \
# 0  Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics      good
#
#    Weight
# 0    90.0

# %%
hero_powers.head(1)
# Out:
#   hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0    3-D Man     True                False               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
#
# [1 rows x 168 columns]

# %%
hero=pd.merge(hero_info, hero_powers, left_on='name', right_on='hero_names', how='inner')

# %%
hero.head(1)
# Out:
#        name Gender Eye color     Race Hair color  Height  Publisher Alignment  \
# 0  Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics      good
#
#    Weight hero_names  ...  Web Creation  Reality Warping  Odin Force  \
# 0    90.0   Abin Sur  ...         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
#
# [1 rows x 177 columns]

# %%
hero.shape
# Out:
# (537, 177)

# %% [markdown]
# # Renaming columns

# %%
hero.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 537 entries, 0 to 536
# Data columns (total 177 columns):
#  #    Column                        Dtype
# ---   ------                        -----
#  0    name                          object
#  1    Gender                        object
#  2    Eye color                     object
#  3    Race                          object
#  4    Hair color                    object
#  5    Height                        int64
#  6    Publisher                     object
#  7    Alignment                     object
#  8    Weight                        float64
#  9    hero_names                    object
#  10   Agility                       bool
#  11   Accelerated Healing           bool
#  12   Lantern Power Ring            bool
#  13   Dimensional Awareness         bool
#  14   Cold Resistance               bool
#  15   Durability                    bool
#  16   Stealth                       bool
#  17   Energy Absorption             bool
#  18   Flight                        bool
#  19   Danger Sense                  bool
#  20   Underwater breathing          bool
#  21   Marksmanship                  bool
#  22   Weapons Master                bool
#  23   Power Augmentation            bool
#  24   Animal Attributes             bool
#  25   Longevity                     bool
#  26   Intelligence                  bool
#  27   Super Strength                bool
#  28   Cryokinesis                   bool
#  29   Telepathy                     bool
#  30   Energy Armor                  bool
#  31   Energy Blasts                 bool
#  32   Duplication                   bool
#  33   Size Changing                 bool
#  34   Density Control               bool
#  35   Stamina                       bool
#  36   Astral Travel                 bool
#  37   Audio Control                 bool
#  38   Dexterity                     bool
#  39   Omnitrix                      bool
#  40   Super Speed                   bool
#  41   Possession                    bool
#  42   Animal Oriented Powers        bool
#  43   Weapon-based Powers           bool
#  44   Electrokinesis                bool
#  45   Darkforce Manipulation        bool
#  46   Death Touch                   bool
#  47   Teleportation                 bool
#  48   Enhanced Senses               bool
#  49   Telekinesis                   bool
#  50   Energy Beams                  bool
#  51   Magic                         bool
#  52   Hyperkinesis                  bool
#  53   Jump                          bool
#  54   Clairvoyance                  bool
#  55   Dimensional Travel            bool
#  56   Power Sense                   bool
#  57   Shapeshifting                 bool
#  58   Peak Human Condition          bool
#  59   Immortality                   bool
#  60   Camouflage                    bool
#  61   Element Control               bool
#  62   Phasing                       bool
#  63   Astral Projection             bool
#  64   Electrical Transport          bool
#  65   Fire Control                  bool
#  66   Projection                    bool
#  67   Summoning                     bool
#  68   Enhanced Memory               bool
#  69   Reflexes                      bool
#  70   Invulnerability               bool
#  71   Energy Constructs             bool
#  72   Force Fields                  bool
#  73   Self-Sustenance               bool
#  74   Anti-Gravity                  bool
#  75   Empathy                       bool
#  76   Power Nullifier               bool
#  77   Radiation Control             bool
#  78   Psionic Powers                bool
#  79   Elasticity                    bool
#  80   Substance Secretion           bool
#  81   Elemental Transmogrification  bool
#  82   Technopath/Cyberpath          bool
#  83   Photographic Reflexes         bool
#  84   Seismic Power                 bool
#  85   Animation                     bool
#  86   Precognition                  bool
#  87   Mind Control                  bool
#  88   Fire Resistance               bool
#  89   Power Absorption              bool
#  90   Enhanced Hearing              bool
#  91   Nova Force                    bool
#  92   Insanity                      bool
#  93   Hypnokinesis                  bool
#  94   Animal Control                bool
#  95   Natural Armor                 bool
#  96   Intangibility                 bool
#  97   Enhanced Sight                bool
#  98   Molecular Manipulation        bool
#  99   Heat Generation               bool
#  100  Adaptation                    bool
#  101  Gliding                       bool
#  102  Power Suit                    bool
#  103  Mind Blast                    bool
#  104  Probability Manipulation      bool
#  105  Gravity Control               bool
#  106  Regeneration                  bool
#  107  Light Control                 bool
#  108  Echolocation                  bool
#  109  Levitation                    bool
#  110  Toxin and Disease Control     bool
#  111  Banish                        bool
#  112  Energy Manipulation           bool
#  113  Heat Resistance               bool
#  114  Natural Weapons               bool
#  115  Time Travel                   bool
#  116  Enhanced Smell                bool
#  117  Illusions                     bool
#  118  Thirstokinesis                bool
#  119  Hair Manipulation             bool
#  120  Illumination                  bool
#  121  Omnipotent                    bool
#  122  Cloaking                      bool
#  123  Changing Armor                bool
#  124  Power Cosmic                  bool
#  125  Biokinesis                    bool
#  126  Water Control                 bool
#  127  Radiation Immunity            bool
#  128  Vision - Telescopic           bool
#  129  Toxin and Disease Resistance  bool
#  130  Spatial Awareness             bool
#  131  Energy Resistance             bool
#  132  Telepathy Resistance          bool
#  133  Molecular Combustion          bool
#  134  Omnilingualism                bool
#  135  Portal Creation               bool
#  136  Magnetism                     bool
#  137  Mind Control Resistance       bool
#  138  Plant Control                 bool
#  139  Sonar                         bool
#  140  Sonic Scream                  bool
#  141  Time Manipulation             bool
#  142  Enhanced Touch                bool
#  143  Magic Resistance              bool
#  144  Invisibility                  bool
#  145  Sub-Mariner                   bool
#  146  Radiation Absorption          bool
#  147  Intuitive aptitude            bool
#  148  Vision - Microscopic          bool
#  149  Melting                       bool
#  150  Wind Control                  bool
#  151  Super Breath                  bool
#  152  Wallcrawling                  bool
#  153  Vision - Night                bool
#  154  Vision - Infrared             bool
#  155  Grim Reaping                  bool
#  156  Matter Absorption             bool
#  157  The Force                     bool
#  158  Resurrection                  bool
#  159  Terrakinesis                  bool
#  160  Vision - Heat                 bool
#  161  Vitakinesis                   bool
#  162  Radar Sense                   bool
#  163  Qwardian Power Ring           bool
#  164  Weather Control               bool
#  165  Vision - X-Ray                bool
#  166  Vision - Thermal              bool
#  167  Web Creation                  bool
#  168  Reality Warping               bool
#  169  Odin Force                    bool
#  170  Symbiote Costume              bool
#  171  Speed Force                   bool
#  172  Phoenix Force                 bool
#  173  Molecular Dissipation         bool
#  174  Vision - Cryo                 bool
#  175  Omnipresent                   bool
#  176  Omniscient                    bool
# dtypes: bool(167), float64(1), int64(1), object(8)
# memory usage: 133.7+ KB

# %%
hero.columns
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Alignment', 'Weight', 'hero_names',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=177)

# %%
hero.columns=hero.columns.str.lower()

# %%
hero.head(1)
# Out:
#        name gender eye color     race hair color  height  publisher alignment  \
# 0  Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics      good
#
#    weight hero_names  ...  web creation  reality warping  odin force  \
# 0    90.0   Abin Sur  ...         False            False       False
#
#    symbiote costume  speed force  phoenix force  molecular dissipation  \
# 0             False        False          False                  False
#
#    vision - cryo  omnipresent  omniscient
# 0          False        False       False
#
# [1 rows x 177 columns]

# %%
# renaming
hero=hero.rename(columns={'hero_names' : 'hero name'})

# %%
# make all columns string.upper
hero = hero.rename(columns=str.upper)

# %%
hero.head(2)
# Out:
#            NAME GENDER EYE COLOR     RACE HAIR COLOR  HEIGHT  PUBLISHER  \
# 0      Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics
# 1  Adam Strange   Male      blue    Human      Blond     185  DC Comics
#
#   ALIGNMENT  WEIGHT     HERO NAME  ...  WEB CREATION  REALITY WARPING  \
# 0      good    90.0      Abin Sur  ...         False            False
# 1      good    88.0  Adam Strange  ...         False            False
#
#    ODIN FORCE  SYMBIOTE COSTUME  SPEED FORCE  PHOENIX FORCE  \
# 0       False             False        False          False
# 1       False             False        False          False
#
#    MOLECULAR DISSIPATION  VISION - CRYO  OMNIPRESENT  OMNISCIENT
# 0                  False          False        False       False
# 1                  False          False        False       False
#
# [2 rows x 177 columns]

# %%
hero=hero.rename(mapper=str.lower, axis=1)

# %%
hero.head(2)
# Out:
#            name gender eye color     race hair color  height  publisher  \
# 0      Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics
# 1  Adam Strange   Male      blue    Human      Blond     185  DC Comics
#
#   alignment  weight     hero name  ...  web creation  reality warping  \
# 0      good    90.0      Abin Sur  ...         False            False
# 1      good    88.0  Adam Strange  ...         False            False
#
#    odin force  symbiote costume  speed force  phoenix force  \
# 0       False             False        False          False
# 1       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
#
# [2 rows x 177 columns]

# %%
hero.to_pickle('hero_pkl')

# %%
# hero as the dataframe and 'name' as the column name
type(hero['name'])    # columns in a pandas dataframe are pandas series
# Out:
# pandas.core.series.Series

# %%
hero.columns
# Out:
# Index(['name', 'gender', 'eye color', 'race', 'hair color', 'height',
#        'publisher', 'alignment', 'weight', 'hero name',
#        ...
#        'web creation', 'reality warping', 'odin force', 'symbiote costume',
#        'speed force', 'phoenix force', 'molecular dissipation',
#        'vision - cryo', 'omnipresent', 'omniscient'],
#       dtype='object', length=177)

# %%
type(hero[['name', 'weight', 'height']])
# Out:
# pandas.core.frame.DataFrame

# %%
hero.select_dtypes(include='number')
# Out:
#      height  weight
# 0       185    90.0
# 1       185    88.0
# 2       180    90.0
# 3       257   173.0
# 4       183    83.0
# ..      ...     ...
# 532     155    50.0
# 533     175    61.0
# 534     183    83.0
# 535     165    52.0
# 536     305   -99.0
#
# [537 rows x 2 columns]

# %%
hero.select_dtypes(exclude='number')
# Out:
#                 name  gender eye color            race        hair color  \
# 0           Abin Sur    Male      blue         Ungaran           No Hair
# 1       Adam Strange    Male      blue           Human             Blond
# 2         Alan Scott    Male      blue               -             Blond
# 3              Amazo    Male       red         Android                 -
# 4         Animal Man    Male      blue           Human             Blond
# ..               ...     ...       ...             ...               ...
# 532             X-23  Female     green  Mutant / Clone             Black
# 533            X-Man    Male      blue               -             Brown
# 534     Yellowjacket    Male      blue           Human             Blond
# 535  Yellowjacket II  Female      blue           Human  Strawberry Blond
# 536             Ymir    Male     white     Frost Giant           No Hair
#
#          publisher alignment        hero name  agility  accelerated healing  \
# 0        DC Comics      good         Abin Sur    False                False
# 1        DC Comics      good     Adam Strange    False                False
# 2        DC Comics      good       Alan Scott    False                False
# 3        DC Comics       bad            Amazo     True                False
# 4        DC Comics      good       Animal Man    False                False
# ..             ...       ...              ...      ...                  ...
# 532  Marvel Comics      good             X-23     True                 True
# 533  Marvel Comics      good            X-Man    False                False
# 534  Marvel Comics      good     Yellowjacket    False                False
# 535  Marvel Comics      good  Yellowjacket II    False                False
# 536  Marvel Comics      good             Ymir    False                False
#
#      ...  web creation  reality warping  odin force  symbiote costume  \
# 0    ...         False            False       False             False
# 1    ...         False            False       False             False
# 2    ...         False            False       False             False
# 3    ...         False            False       False             False
# 4    ...         False            False       False             False
# ..   ...           ...              ...         ...               ...
# 532  ...         False            False       False             False
# 533  ...         False            False       False             False
# 534  ...         False            False       False             False
# 535  ...         False            False       False             False
# 536  ...         False            False       False             False
#
#      speed force  phoenix force  molecular dissipation  vision - cryo  \
# 0          False          False                  False          False
# 1          False          False                  False          False
# 2          False          False                  False          False
# 3          False          False                  False          False
# 4          False          False                  False          False
# ..           ...            ...                    ...            ...
# 532        False          False                  False          False
# 533        False          False                  False          False
# 534        False          False                  False          False
# 535        False          False                  False          False
# 536        False          False                  False          False
#
#      omnipresent  omniscient
# 0          False       False
# 1          False       False
# 2          False       False
# 3          False       False
# 4          False       False
# ..           ...         ...
# 532        False       False
# 533        False       False
# 534        False       False
# 535        False       False
# 536        False       False
#
# [537 rows x 175 columns]

# %%
hero.head()
# Out:
#            name gender eye color     race hair color  height  publisher  \
# 0      Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics
# 1  Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2    Alan Scott   Male      blue        -      Blond     180  DC Comics
# 3         Amazo   Male       red  Android          -     257  DC Comics
# 4    Animal Man   Male      blue    Human      Blond     183  DC Comics
#
#   alignment  weight     hero name  ...  web creation  reality warping  \
# 0      good    90.0      Abin Sur  ...         False            False
# 1      good    88.0  Adam Strange  ...         False            False
# 2      good    90.0    Alan Scott  ...         False            False
# 3       bad   173.0         Amazo  ...         False            False
# 4      good    83.0    Animal Man  ...         False            False
#
#    odin force  symbiote costume  speed force  phoenix force  \
# 0       False             False        False          False
# 1       False             False        False          False
# 2       False             False        False          False
# 3       False             False        False          False
# 4       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient
# 0                  False          False        False       False
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
#
# [5 rows x 177 columns]

# %%
# returns panads series storing data at the first row
hero.loc[1:4]
# Out:
#            name gender eye color     race hair color  height  publisher  \
# 1  Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2    Alan Scott   Male      blue        -      Blond     180  DC Comics
# 3         Amazo   Male       red  Android          -     257  DC Comics
# 4    Animal Man   Male      blue    Human      Blond     183  DC Comics
#
#   alignment  weight     hero name  ...  web creation  reality warping  \
# 1      good    88.0  Adam Strange  ...         False            False
# 2      good    90.0    Alan Scott  ...         False            False
# 3       bad   173.0         Amazo  ...         False            False
# 4      good    83.0    Animal Man  ...         False            False
#
#    odin force  symbiote costume  speed force  phoenix force  \
# 1       False             False        False          False
# 2       False             False        False          False
# 3       False             False        False          False
# 4       False             False        False          False
#
#    molecular dissipation  vision - cryo  omnipresent  omniscient
# 1                  False          False        False       False
# 2                  False          False        False       False
# 3                  False          False        False       False
# 4                  False          False        False       False
#
# [4 rows x 177 columns]

# %%
hero=hero.set_index('name')

# %%
hero.head()
# Out:
#              gender eye color     race hair color  height  publisher  \
# name
# Abin Sur       Male      blue  Ungaran    No Hair     185  DC Comics
# Adam Strange   Male      blue    Human      Blond     185  DC Comics
# Alan Scott     Male      blue        -      Blond     180  DC Comics
# Amazo          Male       red  Android          -     257  DC Comics
# Animal Man     Male      blue    Human      Blond     183  DC Comics
#
#              alignment  weight     hero name  agility  ...  web creation  \
# name                                                   ...
# Abin Sur          good    90.0      Abin Sur    False  ...         False
# Adam Strange      good    88.0  Adam Strange    False  ...         False
# Alan Scott        good    90.0    Alan Scott    False  ...         False
# Amazo              bad   173.0         Amazo     True  ...         False
# Animal Man        good    83.0    Animal Man    False  ...         False
#
#               reality warping  odin force  symbiote costume  speed force  \
# name
# Abin Sur                False       False             False        False
# Adam Strange            False       False             False        False
# Alan Scott              False       False             False        False
# Amazo                   False       False             False        False
# Animal Man              False       False             False        False
#
#               phoenix force  molecular dissipation  vision - cryo  \
# name
# Abin Sur              False                  False          False
# Adam Strange          False                  False          False
# Alan Scott            False                  False          False
# Amazo                 False                  False          False
# Animal Man            False                  False          False
#
#               omnipresent  omniscient
# name
# Abin Sur            False       False
# Adam Strange        False       False
# Alan Scott          False       False
# Amazo               False       False
# Animal Man          False       False
#
# [5 rows x 176 columns]

# %%
hero.index
# Out:
# Index(['Abin Sur', 'Adam Strange', 'Alan Scott', 'Amazo', 'Animal Man',
#        'Anti-Monitor', 'Aquababy', 'Aqualad', 'Aquaman', 'Atlas',
#        ...
#        'Weapon XI', 'Winter Soldier', 'Wolfsbane', 'Wolverine', 'Wonder Man',
#        'X-23', 'X-Man', 'Yellowjacket', 'Yellowjacket II', 'Ymir'],
#       dtype='object', name='name', length=537)

# %%
hero.loc['Adam Strange' : 'Animal Man']
# Out:
#              gender eye color     race hair color  height  publisher  \
# name
# Adam Strange   Male      blue    Human      Blond     185  DC Comics
# Alan Scott     Male      blue        -      Blond     180  DC Comics
# Amazo          Male       red  Android          -     257  DC Comics
# Animal Man     Male      blue    Human      Blond     183  DC Comics
#
#              alignment  weight     hero name  agility  ...  web creation  \
# name                                                   ...
# Adam Strange      good    88.0  Adam Strange    False  ...         False
# Alan Scott        good    90.0    Alan Scott    False  ...         False
# Amazo              bad   173.0         Amazo     True  ...         False
# Animal Man        good    83.0    Animal Man    False  ...         False
#
#               reality warping  odin force  symbiote costume  speed force  \
# name
# Adam Strange            False       False             False        False
# Alan Scott              False       False             False        False
# Amazo                   False       False             False        False
# Animal Man              False       False             False        False
#
#               phoenix force  molecular dissipation  vision - cryo  \
# name
# Adam Strange          False                  False          False
# Alan Scott            False                  False          False
# Amazo                 False                  False          False
# Animal Man            False                  False          False
#
#               omnipresent  omniscient
# name
# Adam Strange        False       False
# Alan Scott          False       False
# Amazo               False       False
# Animal Man          False       False
#
# [4 rows x 176 columns]

# %%
hero.loc[['Spider-Man', 'Superman', 'Wonder Woman']]
# Out:
#               gender eye color        race hair color  height      publisher  \
# name
# Spider-Man      Male     hazel       Human      Brown     178  Marvel Comics
# Spider-Man         -       red       Human      Brown     178  Marvel Comics
# Spider-Man      Male     brown       Human      Black     157  Marvel Comics
# Superman        Male      blue  Kryptonian      Black     191      DC Comics
# Wonder Woman  Female      blue      Amazon      Black     183      DC Comics
#
#              alignment  weight     hero name  agility  ...  web creation  \
# name                                                   ...
# Spider-Man        good    74.0    Spider-Man     True  ...          True
# Spider-Man        good    77.0    Spider-Man     True  ...          True
# Spider-Man        good    56.0    Spider-Man     True  ...          True
# Superman          good   101.0      Superman     True  ...         False
# Wonder Woman      good    74.0  Wonder Woman    False  ...         False
#
#               reality warping  odin force  symbiote costume  speed force  \
# name
# Spider-Man              False       False             False        False
# Spider-Man              False       False             False        False
# Spider-Man              False       False             False        False
# Superman                False       False             False        False
# Wonder Woman            False       False             False        False
#
#               phoenix force  molecular dissipation  vision - cryo  \
# name
# Spider-Man            False                  False          False
# Spider-Man            False                  False          False
# Spider-Man            False                  False          False
# Superman              False                  False          False
# Wonder Woman          False                  False          False
#
#               omnipresent  omniscient
# name
# Spider-Man          False       False
# Spider-Man          False       False
# Spider-Man          False       False
# Superman            False       False
# Wonder Woman        False       False
#
# [5 rows x 176 columns]

# %%
hero.head()
# Out:
#              gender eye color     race hair color  height  publisher  \
# name
# Abin Sur       Male      blue  Ungaran    No Hair     185  DC Comics
# Adam Strange   Male      blue    Human      Blond     185  DC Comics
# Alan Scott     Male      blue        -      Blond     180  DC Comics
# Amazo          Male       red  Android          -     257  DC Comics
# Animal Man     Male      blue    Human      Blond     183  DC Comics
#
#              alignment  weight     hero name  agility  ...  web creation  \
# name                                                   ...
# Abin Sur          good    90.0      Abin Sur    False  ...         False
# Adam Strange      good    88.0  Adam Strange    False  ...         False
# Alan Scott        good    90.0    Alan Scott    False  ...         False
# Amazo              bad   173.0         Amazo     True  ...         False
# Animal Man        good    83.0    Animal Man    False  ...         False
#
#               reality warping  odin force  symbiote costume  speed force  \
# name
# Abin Sur                False       False             False        False
# Adam Strange            False       False             False        False
# Alan Scott              False       False             False        False
# Amazo                   False       False             False        False
# Animal Man              False       False             False        False
#
#               phoenix force  molecular dissipation  vision - cryo  \
# name
# Abin Sur              False                  False          False
# Adam Strange          False                  False          False
# Alan Scott            False                  False          False
# Amazo                 False                  False          False
# Animal Man            False                  False          False
#
#               omnipresent  omniscient
# name
# Abin Sur            False       False
# Adam Strange        False       False
# Alan Scott          False       False
# Amazo               False       False
# Animal Man          False       False
#
# [5 rows x 176 columns]

# %%
hero.iloc[0]
# Out:
# gender                      Male
# eye color                   blue
# race                     Ungaran
# hair color               No Hair
# height                       185
#                           ...
# phoenix force              False
# molecular dissipation      False
# vision - cryo              False
# omnipresent                False
# omniscient                 False
# Name: Abin Sur, Length: 176, dtype: object

# %%
hero.iloc[1:4]
# Out:
#              gender eye color     race hair color  height  publisher  \
# name
# Adam Strange   Male      blue    Human      Blond     185  DC Comics
# Alan Scott     Male      blue        -      Blond     180  DC Comics
# Amazo          Male       red  Android          -     257  DC Comics
#
#              alignment  weight     hero name  agility  ...  web creation  \
# name                                                   ...
# Adam Strange      good    88.0  Adam Strange    False  ...         False
# Alan Scott        good    90.0    Alan Scott    False  ...         False
# Amazo              bad   173.0         Amazo     True  ...         False
#
#               reality warping  odin force  symbiote costume  speed force  \
# name
# Adam Strange            False       False             False        False
# Alan Scott              False       False             False        False
# Amazo                   False       False             False        False
#
#               phoenix force  molecular dissipation  vision - cryo  \
# name
# Adam Strange          False                  False          False
# Alan Scott            False                  False          False
# Amazo                 False                  False          False
#
#               omnipresent  omniscient
# name
# Adam Strange        False       False
# Alan Scott          False       False
# Amazo               False       False
#
# [3 rows x 176 columns]

# %%
hero.iloc[[3,1,2]]
# Out:
#              gender eye color     race hair color  height  publisher  \
# name
# Amazo          Male       red  Android          -     257  DC Comics
# Adam Strange   Male      blue    Human      Blond     185  DC Comics
# Alan Scott     Male      blue        -      Blond     180  DC Comics
#
#              alignment  weight     hero name  agility  ...  web creation  \
# name                                                   ...
# Amazo              bad   173.0         Amazo     True  ...         False
# Adam Strange      good    88.0  Adam Strange    False  ...         False
# Alan Scott        good    90.0    Alan Scott    False  ...         False
#
#               reality warping  odin force  symbiote costume  speed force  \
# name
# Amazo                   False       False             False        False
# Adam Strange            False       False             False        False
# Alan Scott              False       False             False        False
#
#               phoenix force  molecular dissipation  vision - cryo  \
# name
# Amazo                 False                  False          False
# Adam Strange          False                  False          False
# Alan Scott            False                  False          False
#
#               omnipresent  omniscient
# name
# Amazo               False       False
# Adam Strange        False       False
# Alan Scott          False       False
#
# [3 rows x 176 columns]

# %%
hero['alignment']=='bad'
# Out:
# name
# Abin Sur           False
# Adam Strange       False
# Alan Scott         False
# Amazo               True
# Animal Man         False
#                    ...
# X-23               False
# X-Man              False
# Yellowjacket       False
# Yellowjacket II    False
# Ymir               False
# Name: alignment, Length: 537, dtype: bool

# %%
hero.loc[hero['alignment']=='bad']
# Out:
#               gender eye color           race hair color  height  \
# name
# Amazo           Male       red        Android          -     257
# Anti-Monitor    Male    yellow  God / Eternal    No Hair      61
# Atlas           Male      blue  God / Eternal      Brown     198
# Bane            Male         -          Human          -     203
# Big Barda     Female      blue        New God      Black     188
# ...              ...       ...            ...        ...     ...
# Venom II        Male     brown              -      Black     175
# Venom III       Male     brown       Symbiote      Brown     229
# Vulture         Male     brown          Human    No Hair     180
# Walrus          Male      blue          Human      Black     183
# Weapon XI       Male         -              -          -     -99
#
#                   publisher alignment  weight     hero name  agility  ...  \
# name                                                                  ...
# Amazo             DC Comics       bad   173.0         Amazo     True  ...
# Anti-Monitor      DC Comics       bad     NaN  Anti-Monitor    False  ...
# Atlas             DC Comics       bad   126.0         Atlas    False  ...
# Bane              DC Comics       bad   180.0          Bane    False  ...
# Big Barda         DC Comics       bad   135.0     Big Barda     True  ...
# ...                     ...       ...     ...           ...      ...  ...
# Venom II      Marvel Comics       bad    50.0      Venom II     True  ...
# Venom III     Marvel Comics       bad   334.0     Venom III     True  ...
# Vulture       Marvel Comics       bad    79.0       Vulture     True  ...
# Walrus        Marvel Comics       bad   162.0        Walrus    False  ...
# Weapon XI     Marvel Comics       bad   -99.0     Weapon XI     True  ...
#
#               web creation  reality warping  odin force  symbiote costume  \
# name
# Amazo                False            False       False             False
# Anti-Monitor         False             True       False             False
# Atlas                False            False       False             False
# Bane                 False            False       False             False
# Big Barda            False            False       False             False
# ...                    ...              ...         ...               ...
# Venom II             False            False       False             False
# Venom III            False            False       False              True
# Vulture              False            False       False             False
# Walrus               False            False       False             False
# Weapon XI            False            False       False             False
#
#               speed force  phoenix force  molecular dissipation  \
# name
# Amazo               False          False                  False
# Anti-Monitor        False          False                  False
# Atlas               False          False                  False
# Bane                False          False                  False
# Big Barda           False          False                  False
# ...                   ...            ...                    ...
# Venom II            False          False                  False
# Venom III           False          False                  False
# Vulture             False          False                  False
# Walrus              False          False                  False
# Weapon XI           False          False                  False
#
#               vision - cryo  omnipresent  omniscient
# name
# Amazo                 False        False       False
# Anti-Monitor          False        False       False
# Atlas                 False        False       False
# Bane                  False        False       False
# Big Barda             False        False       False
# ...                     ...          ...         ...
# Venom II              False        False       False
# Venom III             False        False       False
# Vulture               False        False       False
# Walrus                False        False       False
# Weapon XI             False        False       False
#
# [162 rows x 176 columns]

# %%
mask=hero['alignment']=='bad'

# %%
mask.values
# Out:
# array([False, False, False,  True, False,  True, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False,  True, False,  True, False, False, False,
#        False,  True, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False,  True,
#         True,  True,  True, False, False,  True,  True, False,  True,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False,  True,
#         True,  True,  True,  True, False, False, False,  True, False,
#        False, False,  True, False, False, False, False, False, False,
#        False,  True, False, False, False,  True,  True, False,  True,
#        False, False,  True, False, False,  True, False, False, False,
#        False,  True,  True, False,  True, False, False, False, False,
#        False,  True,  True, False, False, False, False, False,  True,
#         True,  True, False, False, False,  True,  True, False,  True,
#        False,  True, False, False, False, False, False, False,  True,
#         True, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False,  True,  True, False,  True,
#        False, False, False, False, False, False, False, False,  True,
#        False,  True, False, False,  True, False, False,  True, False,
#        False, False,  True,  True, False, False, False, False,  True,
#        False,  True,  True,  True, False, False,  True,  True,  True,
#        False, False, False,  True, False, False, False,  True, False,
#        False,  True, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False,  True, False, False,
#         True,  True, False,  True, False, False, False,  True, False,
#        False,  True,  True, False, False, False, False,  True,  True,
#         True,  True,  True, False,  True, False, False, False,  True,
#        False, False,  True, False, False, False, False, False,  True,
#        False, False, False, False,  True, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True,  True,  True, False,  True,  True,  True,
#        False, False,  True,  True, False,  True,  True, False, False,
#         True,  True,  True,  True, False,  True, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False,  True, False, False,  True,  True,
#        False, False, False, False, False, False,  True, False, False,
#        False,  True, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False,  True, False,  True,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#        False,  True,  True, False, False, False, False,  True, False,
#         True,  True, False, False,  True, False, False, False, False,
#        False,  True, False, False,  True,  True, False,  True,  True,
#        False,  True,  True,  True, False, False, False,  True,  True,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False,  True, False, False,  True, False,
#        False,  True, False, False,  True,  True, False, False,  True,
#        False,  True,  True, False, False, False,  True, False, False,
#        False, False, False,  True,  True,  True,  True, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False,  True, False,  True, False,  True, False, False,
#        False, False, False, False, False,  True, False,  True, False,
#        False, False, False, False,  True,  True, False,  True,  True,
#         True,  True, False, False, False, False, False,  True,  True,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False])

# %%
hero.iloc[mask.values]
# Out:
#               gender eye color           race hair color  height  \
# name
# Amazo           Male       red        Android          -     257
# Anti-Monitor    Male    yellow  God / Eternal    No Hair      61
# Atlas           Male      blue  God / Eternal      Brown     198
# Bane            Male         -          Human          -     203
# Big Barda     Female      blue        New God      Black     188
# ...              ...       ...            ...        ...     ...
# Venom II        Male     brown              -      Black     175
# Venom III       Male     brown       Symbiote      Brown     229
# Vulture         Male     brown          Human    No Hair     180
# Walrus          Male      blue          Human      Black     183
# Weapon XI       Male         -              -          -     -99
#
#                   publisher alignment  weight     hero name  agility  ...  \
# name                                                                  ...
# Amazo             DC Comics       bad   173.0         Amazo     True  ...
# Anti-Monitor      DC Comics       bad     NaN  Anti-Monitor    False  ...
# Atlas             DC Comics       bad   126.0         Atlas    False  ...
# Bane              DC Comics       bad   180.0          Bane    False  ...
# Big Barda         DC Comics       bad   135.0     Big Barda     True  ...
# ...                     ...       ...     ...           ...      ...  ...
# Venom II      Marvel Comics       bad    50.0      Venom II     True  ...
# Venom III     Marvel Comics       bad   334.0     Venom III     True  ...
# Vulture       Marvel Comics       bad    79.0       Vulture     True  ...
# Walrus        Marvel Comics       bad   162.0        Walrus    False  ...
# Weapon XI     Marvel Comics       bad   -99.0     Weapon XI     True  ...
#
#               web creation  reality warping  odin force  symbiote costume  \
# name
# Amazo                False            False       False             False
# Anti-Monitor         False             True       False             False
# Atlas                False            False       False             False
# Bane                 False            False       False             False
# Big Barda            False            False       False             False
# ...                    ...              ...         ...               ...
# Venom II             False            False       False             False
# Venom III            False            False       False              True
# Vulture              False            False       False             False
# Walrus               False            False       False             False
# Weapon XI            False            False       False             False
#
#               speed force  phoenix force  molecular dissipation  \
# name
# Amazo               False          False                  False
# Anti-Monitor        False          False                  False
# Atlas               False          False                  False
# Bane                False          False                  False
# Big Barda           False          False                  False
# ...                   ...            ...                    ...
# Venom II            False          False                  False
# Venom III           False          False                  False
# Vulture             False          False                  False
# Walrus              False          False                  False
# Weapon XI           False          False                  False
#
#               vision - cryo  omnipresent  omniscient
# name
# Amazo                 False        False       False
# Anti-Monitor          False        False       False
# Atlas                 False        False       False
# Bane                  False        False       False
# Big Barda             False        False       False
# ...                     ...          ...         ...
# Venom II              False        False       False
# Venom III             False        False       False
# Vulture               False        False       False
# Walrus                False        False       False
# Weapon XI             False        False       False
#
# [162 rows x 176 columns]

# %%
# returns the DataFrame where alignment == 'bad'
hero[hero['alignment']=='bad']
# Out:
#               gender eye color           race hair color  height  \
# name
# Amazo           Male       red        Android          -     257
# Anti-Monitor    Male    yellow  God / Eternal    No Hair      61
# Atlas           Male      blue  God / Eternal      Brown     198
# Bane            Male         -          Human          -     203
# Big Barda     Female      blue        New God      Black     188
# ...              ...       ...            ...        ...     ...
# Venom II        Male     brown              -      Black     175
# Venom III       Male     brown       Symbiote      Brown     229
# Vulture         Male     brown          Human    No Hair     180
# Walrus          Male      blue          Human      Black     183
# Weapon XI       Male         -              -          -     -99
#
#                   publisher alignment  weight     hero name  agility  ...  \
# name                                                                  ...
# Amazo             DC Comics       bad   173.0         Amazo     True  ...
# Anti-Monitor      DC Comics       bad     NaN  Anti-Monitor    False  ...
# Atlas             DC Comics       bad   126.0         Atlas    False  ...
# Bane              DC Comics       bad   180.0          Bane    False  ...
# Big Barda         DC Comics       bad   135.0     Big Barda     True  ...
# ...                     ...       ...     ...           ...      ...  ...
# Venom II      Marvel Comics       bad    50.0      Venom II     True  ...
# Venom III     Marvel Comics       bad   334.0     Venom III     True  ...
# Vulture       Marvel Comics       bad    79.0       Vulture     True  ...
# Walrus        Marvel Comics       bad   162.0        Walrus    False  ...
# Weapon XI     Marvel Comics       bad   -99.0     Weapon XI     True  ...
#
#               web creation  reality warping  odin force  symbiote costume  \
# name
# Amazo                False            False       False             False
# Anti-Monitor         False             True       False             False
# Atlas                False            False       False             False
# Bane                 False            False       False             False
# Big Barda            False            False       False             False
# ...                    ...              ...         ...               ...
# Venom II             False            False       False             False
# Venom III            False            False       False              True
# Vulture              False            False       False             False
# Walrus               False            False       False             False
# Weapon XI            False            False       False             False
#
#               speed force  phoenix force  molecular dissipation  \
# name
# Amazo               False          False                  False
# Anti-Monitor        False          False                  False
# Atlas               False          False                  False
# Bane                False          False                  False
# Big Barda           False          False                  False
# ...                   ...            ...                    ...
# Venom II            False          False                  False
# Venom III           False          False                  False
# Vulture             False          False                  False
# Walrus              False          False                  False
# Weapon XI           False          False                  False
#
#               vision - cryo  omnipresent  omniscient
# name
# Amazo                 False        False       False
# Anti-Monitor          False        False       False
# Atlas                 False        False       False
# Bane                  False        False       False
# Big Barda             False        False       False
# ...                     ...          ...         ...
# Venom II              False        False       False
# Venom III             False        False       False
# Vulture               False        False       False
# Walrus                False        False       False
# Weapon XI             False        False       False
#
# [162 rows x 176 columns]

# %%
# returns boolean where 'aliggnment'=='bad' and 'height'>=200
(hero['alignment']=='bad') & (hero['height']>=200)
# Out:
# name
# Abin Sur           False
# Adam Strange       False
# Alan Scott         False
# Amazo               True
# Animal Man         False
#                    ...
# X-23               False
# X-Man              False
# Yellowjacket       False
# Yellowjacket II    False
# Ymir               False
# Length: 537, dtype: bool

# %%
# returns the DataFrame where 'alignment'=='bad' and 'height'>=200
hero[(hero['alignment']=='bad') & (hero['height']>=200)]
# Out:
#                 gender eye color               race hair color  height  \
# name
# Amazo             Male       red            Android          -     257
# Bane              Male         -              Human          -     203
# Darkseid          Male       red            New God    No Hair     267
# Doomsday          Male       red              Alien      White     244
# Killer Croc       Male       red          Metahuman    No Hair     244
# Solomon Grundy    Male     black             Zombie      White     279
# Abomination       Male     green  Human / Radiation    No Hair     203
# Apocalypse        Male       red             Mutant      Black     213
# Bloodaxe        Female      blue              Human      Brown     218
# Doctor Doom       Male     brown              Human      Brown     201
# Doctor Doom II    Male     brown                  -      Brown     201
# Frenzy          Female     brown                  -      Black     211
# Hela            Female     green          Asgardian      Black     213
# Lizard            Male       red              Human    No Hair     203
# MODOK             Male     white             Cyborg     Brownn     366
# Onslaught         Male       red             Mutant    No Hair     305
# Scorpion          Male     brown              Human      Brown     211
# Thanos            Male       red            Eternal    No Hair     201
# Ultron            Male       red            Android          -     206
# Venom III         Male     brown           Symbiote      Brown     229
#
#                     publisher alignment  weight       hero name  agility  ...  \
# name                                                                      ...
# Amazo               DC Comics       bad   173.0           Amazo     True  ...
# Bane                DC Comics       bad   180.0            Bane    False  ...
# Darkseid            DC Comics       bad   817.0        Darkseid     True  ...
# Doomsday            DC Comics       bad   412.0        Doomsday     True  ...
# Killer Croc         DC Comics       bad   356.0     Killer Croc     True  ...
# Solomon Grundy      DC Comics       bad   437.0  Solomon Grundy    False  ...
# Abomination     Marvel Comics       bad   441.0     Abomination    False  ...
# Apocalypse      Marvel Comics       bad   135.0      Apocalypse     True  ...
# Bloodaxe        Marvel Comics       bad   495.0        Bloodaxe     True  ...
# Doctor Doom     Marvel Comics       bad   187.0     Doctor Doom    False  ...
# Doctor Doom II  Marvel Comics       bad   132.0  Doctor Doom II    False  ...
# Frenzy          Marvel Comics       bad   104.0          Frenzy    False  ...
# Hela            Marvel Comics       bad   225.0            Hela     True  ...
# Lizard          Marvel Comics       bad   230.0          Lizard    False  ...
# MODOK           Marvel Comics       bad   338.0           MODOK     True  ...
# Onslaught       Marvel Comics       bad   405.0       Onslaught    False  ...
# Scorpion        Marvel Comics       bad   310.0        Scorpion     True  ...
# Thanos          Marvel Comics       bad   443.0          Thanos     True  ...
# Ultron          Marvel Comics       bad   331.0          Ultron     True  ...
# Venom III       Marvel Comics       bad   334.0       Venom III     True  ...
#
#                 web creation  reality warping  odin force  symbiote costume  \
# name
# Amazo                  False            False       False             False
# Bane                   False            False       False             False
# Darkseid               False            False       False             False
# Doomsday               False            False       False             False
# Killer Croc            False            False       False             False
# Solomon Grundy         False            False       False             False
# Abomination            False            False       False             False
# Apocalypse             False            False       False             False
# Bloodaxe               False            False       False             False
# Doctor Doom            False            False       False             False
# Doctor Doom II         False            False       False             False
# Frenzy                 False            False       False             False
# Hela                   False            False       False             False
# Lizard                 False            False       False             False
# MODOK                  False            False       False             False
# Onslaught              False             True       False             False
# Scorpion               False            False       False             False
# Thanos                 False             True       False             False
# Ultron                 False            False       False             False
# Venom III              False            False       False              True
#
#                 speed force  phoenix force  molecular dissipation  \
# name
# Amazo                 False          False                  False
# Bane                  False          False                  False
# Darkseid              False          False                  False
# Doomsday              False          False                  False
# Killer Croc           False          False                  False
# Solomon Grundy        False          False                  False
# Abomination           False          False                  False
# Apocalypse            False          False                  False
# Bloodaxe              False          False                  False
# Doctor Doom           False          False                  False
# Doctor Doom II        False          False                  False
# Frenzy                False          False                  False
# Hela                  False          False                  False
# Lizard                False          False                  False
# MODOK                 False          False                  False
# Onslaught             False          False                  False
# Scorpion              False          False                  False
# Thanos                False          False                  False
# Ultron                False          False                  False
# Venom III             False          False                  False
#
#                 vision - cryo  omnipresent  omniscient
# name
# Amazo                   False        False       False
# Bane                    False        False       False
# Darkseid                False        False       False
# Doomsday                False        False       False
# Killer Croc             False        False       False
# Solomon Grundy          False        False       False
# Abomination             False        False       False
# Apocalypse              False        False       False
# Bloodaxe                False        False       False
# Doctor Doom             False        False       False
# Doctor Doom II          False        False       False
# Frenzy                  False        False       False
# Hela                    False        False       False
# Lizard                  False        False       False
# MODOK                   False        False       False
# Onslaught               False        False       False
# Scorpion                False        False       False
# Thanos                  False        False       False
# Ultron                  False        False       False
# Venom III               False        False       False
#
# [20 rows x 176 columns]

# %% [raw]
# hero[(hero['hair color']=='No Hair') | (hero['hair color']=='Blond')]

# %%
# returns a boolean checking the condition for all rows
hero['hair color'].isin(['No Hair', 'Blond'])
# Out:
# name
# Abin Sur            True
# Adam Strange        True
# Alan Scott          True
# Amazo              False
# Animal Man          True
#                    ...
# X-23               False
# X-Man              False
# Yellowjacket        True
# Yellowjacket II    False
# Ymir                True
# Name: hair color, Length: 537, dtype: bool

# %%
# returns a DataFrame using the above conditional statement
hero[hero['hair color'].isin(['No Hair', 'Blond'])]
# Out:
#              gender eye color           race hair color  height  \
# name
# Abin Sur       Male      blue        Ungaran    No Hair     185
# Adam Strange   Male      blue          Human      Blond     185
# Alan Scott     Male      blue              -      Blond     180
# Animal Man     Male      blue          Human      Blond     183
# Anti-Monitor   Male    yellow  God / Eternal    No Hair      61
# ...             ...       ...            ...        ...     ...
# Vision         Male      gold        Android    No Hair     191
# Vulture        Male     brown          Human    No Hair     180
# Warlock        Male       red              -      Blond     188
# Yellowjacket   Male      blue          Human      Blond     183
# Ymir           Male     white    Frost Giant    No Hair     305
#
#                   publisher alignment  weight     hero name  agility  ...  \
# name                                                                  ...
# Abin Sur          DC Comics      good    90.0      Abin Sur    False  ...
# Adam Strange      DC Comics      good    88.0  Adam Strange    False  ...
# Alan Scott        DC Comics      good    90.0    Alan Scott    False  ...
# Animal Man        DC Comics      good    83.0    Animal Man    False  ...
# Anti-Monitor      DC Comics       bad     NaN  Anti-Monitor    False  ...
# ...                     ...       ...     ...           ...      ...  ...
# Vision        Marvel Comics      good   135.0        Vision    False  ...
# Vulture       Marvel Comics       bad    79.0       Vulture     True  ...
# Warlock       Marvel Comics      good   108.0       Warlock     True  ...
# Yellowjacket  Marvel Comics      good    83.0  Yellowjacket    False  ...
# Ymir          Marvel Comics      good   -99.0          Ymir    False  ...
#
#               web creation  reality warping  odin force  symbiote costume  \
# name
# Abin Sur             False            False       False             False
# Adam Strange         False            False       False             False
# Alan Scott           False            False       False             False
# Animal Man           False            False       False             False
# Anti-Monitor         False             True       False             False
# ...                    ...              ...         ...               ...
# Vision               False            False       False             False
# Vulture              False            False       False             False
# Warlock              False            False       False             False
# Yellowjacket         False            False       False             False
# Ymir                 False            False       False             False
#
#               speed force  phoenix force  molecular dissipation  \
# name
# Abin Sur            False          False                  False
# Adam Strange        False          False                  False
# Alan Scott          False          False                  False
# Animal Man          False          False                  False
# Anti-Monitor        False          False                  False
# ...                   ...            ...                    ...
# Vision              False          False                  False
# Vulture             False          False                  False
# Warlock             False          False                  False
# Yellowjacket        False          False                  False
# Ymir                False          False                  False
#
#               vision - cryo  omnipresent  omniscient
# name
# Abin Sur              False        False       False
# Adam Strange          False        False       False
# Alan Scott            False        False       False
# Animal Man            False        False       False
# Anti-Monitor          False        False       False
# ...                     ...          ...         ...
# Vision                False        False       False
# Vulture               False        False       False
# Warlock               False        False       False
# Yellowjacket          False        False       False
# Ymir                  False        False       False
#
# [137 rows x 176 columns]

# %%
# inverse logic
hero[~hero['alignment'].isin(['good', 'bad'])]
# Out:
#                  gender eye color               race hair color  height  \
# name
# Bizarro            Male     black            Bizarro      Black     191
# Black Flash        Male         -      God / Eternal          -     -99
# Captain Cold       Male     brown              Human      Brown     -99
# Deathstroke        Male      blue              Human      White     193
# Etrigan            Male       red              Demon    No Hair     193
# Indigo           Female         -              Alien     Purple     -99
# Lobo               Male       red           Czarnian      Black     229
# Man-Bat            Male     brown              Human      Brown     -99
# Raven            Female    indigo              Human      Black     165
# Red Hood           Male      blue              Human      Black     183
# Robin VI         Female     green              Human        Red     -99
# Sinestro           Male     black          Korugaran      Black     201
# The Comedian       Male     brown              Human      Black     188
# Trickster          Male      blue              Human      Blond     183
# Anti-Venom         Male      blue           Symbiote      Blond     229
# Blackwulf          Male       red              Alien      White     188
# Copycat          Female       red             Mutant      White     183
# Deadpool           Male     brown             Mutant    No Hair     188
# Galactus           Male     black      Cosmic Entity      Black     876
# Gladiator          Male      blue          Strontian       Blue     198
# Juggernaut         Male      blue              Human        Red     287
# Living Tribunal       -      blue      Cosmic Entity    No Hair     -99
# One-Above-All         -         -      Cosmic Entity          -     -99
# Red Hulk           Male    yellow  Human / Radiation      Black     213
# Sandman            Male     brown              Human      Brown     185
# Sentry             Male      blue             Mutant      Blond     188
# Toad               Male     black             Mutant      Brown     175
# Venompool          Male         -           Symbiote          -     226
#
#                      publisher alignment  weight        hero name  agility  \
# name
# Bizarro              DC Comics   neutral   155.0          Bizarro     True
# Black Flash          DC Comics   neutral     NaN      Black Flash     True
# Captain Cold         DC Comics   neutral     NaN     Captain Cold    False
# Deathstroke          DC Comics   neutral   101.0      Deathstroke     True
# Etrigan              DC Comics   neutral   203.0          Etrigan    False
# Indigo               DC Comics   neutral     NaN           Indigo    False
# Lobo                 DC Comics   neutral   288.0             Lobo    False
# Man-Bat              DC Comics   neutral     NaN          Man-Bat     True
# Raven                DC Comics   neutral    50.0            Raven    False
# Red Hood             DC Comics   neutral    81.0         Red Hood     True
# Robin VI             DC Comics   neutral     NaN         Robin VI     True
# Sinestro             DC Comics   neutral    92.0         Sinestro     True
# The Comedian         DC Comics   neutral   101.0     The Comedian    False
# Trickster            DC Comics         -    81.0        Trickster    False
# Anti-Venom       Marvel Comics         -   358.0       Anti-Venom    False
# Blackwulf        Marvel Comics         -    88.0        Blackwulf    False
# Copycat          Marvel Comics   neutral    67.0          Copycat    False
# Deadpool         Marvel Comics   neutral    95.0         Deadpool     True
# Galactus         Marvel Comics   neutral    16.0         Galactus    False
# Gladiator        Marvel Comics   neutral   268.0        Gladiator     True
# Juggernaut       Marvel Comics   neutral   855.0       Juggernaut    False
# Living Tribunal  Marvel Comics   neutral   -99.0  Living Tribunal     True
# One-Above-All    Marvel Comics   neutral   -99.0    One-Above-All     True
# Red Hulk         Marvel Comics   neutral   630.0         Red Hulk    False
# Sandman          Marvel Comics   neutral   203.0          Sandman     True
# Sentry           Marvel Comics   neutral    87.0           Sentry     True
# Toad             Marvel Comics   neutral    76.0             Toad     True
# Venompool        Marvel Comics         -   -99.0        Venompool     True
#
#                  ...  web creation  reality warping  odin force  \
# name             ...
# Bizarro          ...         False            False       False
# Black Flash      ...         False            False       False
# Captain Cold     ...         False            False       False
# Deathstroke      ...         False            False       False
# Etrigan          ...         False            False       False
# Indigo           ...         False            False       False
# Lobo             ...         False            False       False
# Man-Bat          ...         False            False       False
# Raven            ...         False            False       False
# Red Hood         ...         False            False       False
# Robin VI         ...         False            False       False
# Sinestro         ...         False            False       False
# The Comedian     ...         False            False       False
# Trickster        ...         False            False       False
# Anti-Venom       ...          True            False       False
# Blackwulf        ...         False            False       False
# Copycat          ...         False            False       False
# Deadpool         ...         False            False       False
# Galactus         ...         False            False       False
# Gladiator        ...         False            False       False
# Juggernaut       ...         False            False       False
# Living Tribunal  ...         False             True       False
# One-Above-All    ...         False             True       False
# Red Hulk         ...         False            False       False
# Sandman          ...         False            False       False
# Sentry           ...         False            False       False
# Toad             ...         False            False       False
# Venompool        ...          True            False       False
#
#                  symbiote costume  speed force  phoenix force  \
# name
# Bizarro                     False        False          False
# Black Flash                 False        False          False
# Captain Cold                False        False          False
# Deathstroke                 False        False          False
# Etrigan                     False        False          False
# Indigo                      False        False          False
# Lobo                        False        False          False
# Man-Bat                     False        False          False
# Raven                       False        False          False
# Red Hood                    False        False          False
# Robin VI                    False        False          False
# Sinestro                    False        False          False
# The Comedian                False        False          False
# Trickster                   False        False          False
# Anti-Venom                   True        False          False
# Blackwulf                   False        False          False
# Copycat                     False        False          False
# Deadpool                    False        False          False
# Galactus                    False        False          False
# Gladiator                   False        False          False
# Juggernaut                  False        False          False
# Living Tribunal             False        False          False
# One-Above-All               False        False          False
# Red Hulk                    False        False          False
# Sandman                     False        False          False
# Sentry                      False        False          False
# Toad                        False        False          False
# Venompool                    True        False          False
#
#                  molecular dissipation  vision - cryo  omnipresent  omniscient
# name
# Bizarro                          False           True        False       False
# Black Flash                      False          False        False       False
# Captain Cold                     False          False        False       False
# Deathstroke                      False          False        False       False
# Etrigan                          False          False        False       False
# Indigo                           False          False        False       False
# Lobo                             False          False        False       False
# Man-Bat                          False          False        False       False
# Raven                            False          False        False       False
# Red Hood                         False          False        False       False
# Robin VI                         False          False        False       False
# Sinestro                         False          False        False       False
# The Comedian                     False          False        False       False
# Trickster                        False          False        False       False
# Anti-Venom                       False          False        False       False
# Blackwulf                        False          False        False       False
# Copycat                          False          False        False       False
# Deadpool                         False          False        False       False
# Galactus                         False          False        False       False
# Gladiator                        False          False        False       False
# Juggernaut                       False          False        False       False
# Living Tribunal                  False          False        False       False
# One-Above-All                    False          False         True        True
# Red Hulk                         False          False        False       False
# Sandman                          False          False        False       False
# Sentry                           False          False        False       False
# Toad                             False          False        False       False
# Venompool                        False          False        False       False
#
# [28 rows x 176 columns]

# %%
hero.index
# Out:
# Index(['Abin Sur', 'Adam Strange', 'Alan Scott', 'Amazo', 'Animal Man',
#        'Anti-Monitor', 'Aquababy', 'Aqualad', 'Aquaman', 'Atlas',
#        ...
#        'Weapon XI', 'Winter Soldier', 'Wolfsbane', 'Wolverine', 'Wonder Man',
#        'X-23', 'X-Man', 'Yellowjacket', 'Yellowjacket II', 'Ymir'],
#       dtype='object', name='name', length=537)

# %%
hero=hero.reset_index()

# %%
hero_neutral=hero[hero['alignment']=='neutral']

# %%
hero_neutral.head(3)
# Out:
#             name gender eye color           race hair color  height  \
# 31       Bizarro   Male     black        Bizarro      Black     191
# 35   Black Flash   Male         -  God / Eternal          -     -99
# 48  Captain Cold   Male     brown          Human      Brown     -99
#
#     publisher alignment  weight     hero name  ...  web creation  \
# 31  DC Comics   neutral   155.0       Bizarro  ...         False
# 35  DC Comics   neutral     NaN   Black Flash  ...         False
# 48  DC Comics   neutral     NaN  Captain Cold  ...         False
#
#     reality warping  odin force  symbiote costume  speed force  phoenix force  \
# 31            False       False             False        False          False
# 35            False       False             False        False          False
# 48            False       False             False        False          False
#
#     molecular dissipation  vision - cryo  omnipresent  omniscient
# 31                  False           True        False       False
# 35                  False          False        False       False
# 48                  False          False        False       False
#
# [3 rows x 177 columns]

# %%
# if you want to pass multiple indexes, pass it as a list
hero_neutral.loc[[31, 35, 48]]
# Out:
#             name gender eye color           race hair color  height  \
# 31       Bizarro   Male     black        Bizarro      Black     191
# 35   Black Flash   Male         -  God / Eternal          -     -99
# 48  Captain Cold   Male     brown          Human      Brown     -99
#
#     publisher alignment  weight     hero name  ...  web creation  \
# 31  DC Comics   neutral   155.0       Bizarro  ...         False
# 35  DC Comics   neutral     NaN   Black Flash  ...         False
# 48  DC Comics   neutral     NaN  Captain Cold  ...         False
#
#     reality warping  odin force  symbiote costume  speed force  phoenix force  \
# 31            False       False             False        False          False
# 35            False       False             False        False          False
# 48            False       False             False        False          False
#
#     molecular dissipation  vision - cryo  omnipresent  omniscient
# 31                  False           True        False       False
# 35                  False          False        False       False
# 48                  False          False        False       False
#
# [3 rows x 177 columns]

# %%
hero_neutral.iloc[0]
# Out:
# name                     Bizarro
# gender                      Male
# eye color                  black
# race                     Bizarro
# hair color                 Black
#                           ...
# phoenix force              False
# molecular dissipation      False
# vision - cryo               True
# omnipresent                False
# omniscient                 False
# Name: 31, Length: 177, dtype: object
