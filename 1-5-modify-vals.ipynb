# %%
import pandas as pd
hero=pd.read_pickle('pickle-data/hero_dc.pkl')

# %%
hero.head()
# Out:
#                 name Gender Eye color     Race Hair color  Height  Publisher
# 0           Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics  \
# 1       Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2         Alan Scott   Male      blue        -      Blond     180  DC Comics
# 3  Alfred Pennyworth   Male      blue    Human      Black     178  DC Comics
# 4              Amazo   Male       red  Android          -     257  DC Comics
#
#   Alignment  Weight
# 0      good    90.0
# 1      good    88.0
# 2      good    90.0
# 3      good    72.0
# 4       bad   173.0

# %%
hero.loc[2,'Race']='Unknown'

# %%
hero.head()
# Out:
#                 name Gender Eye color     Race Hair color  Height  Publisher
# 0           Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics  \
# 1       Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2         Alan Scott   Male      blue  Unknown      Blond     180  DC Comics
# 3  Alfred Pennyworth   Male      blue    Human      Black     178  DC Comics
# 4              Amazo   Male       red  Android          -     257  DC Comics
#
#   Alignment  Weight     race
# 0      good    90.0      NaN
# 1      good    88.0      NaN
# 2      good    90.0  Unknown
# 3      good    72.0      NaN
# 4       bad   173.0      NaN

# %%
hero.iloc[2,3]
# Out:
# 'Unknown'

# %%
hero.iloc[2,3]='-'

# %%
hero.head()
# Out:
#                 name Gender Eye color     Race Hair color  Height  Publisher
# 0           Abin Sur   Male      blue  Ungaran    No Hair     185  DC Comics  \
# 1       Adam Strange   Male      blue    Human      Blond     185  DC Comics
# 2         Alan Scott   Male      blue        -      Blond     180  DC Comics
# 3  Alfred Pennyworth   Male      blue    Human      Black     178  DC Comics
# 4              Amazo   Male       red  Android          -     257  DC Comics
#
#   Alignment  Weight     race
# 0      good    90.0      NaN
# 1      good    88.0      NaN
# 2      good    90.0  Unknown
# 3      good    72.0      NaN
# 4       bad   173.0      NaN

# %%
hero.loc[hero['Race']=='-','Race']='Unknown'

# %%
hero[hero['Race']=='Unknown']
# Out:
#                 name  Gender Eye color     Race Hair color  Height  Publisher
# 2         Alan Scott    Male      blue  Unknown      Blond     180  DC Comics  \
# 7           Aquababy    Male      blue  Unknown      Blond     -99  DC Comics
# 12              Atom    Male      blue  Unknown        Red     178  DC Comics
# 13              Atom    Male         -  Unknown          -     -99  DC Comics
# 14         Atom Girl  Female     black  Unknown      Black     168  DC Comics
# ..               ...     ...       ...      ...        ...     ...        ...
# 204  Triplicate Girl  Female    purple  Unknown      Brown     168  DC Comics
# 205         Two-Face    Male         -  Unknown          -     183  DC Comics
# 208             Warp    Male     brown  Unknown      Black     173  DC Comics
# 210         Wildfire    Male         -  Unknown          -     -99  DC Comics
# 214             Zoom    Male       red  Unknown      Brown     185  DC Comics
#
#     Alignment  Weight     race
# 2        good    90.0  Unknown
# 7        good     NaN      NaN
# 12       good    68.0      NaN
# 13       good     NaN      NaN
# 14       good    54.0      NaN
# ..        ...     ...      ...
# 204      good    59.0      NaN
# 205       bad    82.0      NaN
# 208       bad    67.0      NaN
# 210      good     NaN      NaN
# 214       bad    81.0      NaN
#
# [71 rows x 10 columns]

# %%
hero.loc[68]
# Out:
# name          Doctor Fate
# Gender               Male
# Eye color            blue
# Race                Human
# Hair color          Blond
# Height                188
# Publisher       DC Comics
# Alignment            good
# Weight               89.0
# race                  NaN
# Name: 68, dtype: object

# %%
hero.shape
# Out:
# (215, 10)

# %%
hero.loc[10000]=hero.loc[68]

# %%
hero.shape
# Out:
# (216, 10)

# %%
hero.tail()
# Out:
#                name  Gender Eye color      Race Hair color  Height  Publisher
# 211     Wonder Girl  Female      blue  Demi-God      Blond     165  DC Comics  \
# 212    Wonder Woman  Female      blue    Amazon      Black     183  DC Comics
# 213         Zatanna  Female      blue     Human      Black     170  DC Comics
# 214            Zoom    Male       red   Unknown      Brown     185  DC Comics
# 10000   Doctor Fate    Male      blue     Human      Blond     188  DC Comics
#
#       Alignment  Weight race
# 211        good    51.0  NaN
# 212        good    74.0  NaN
# 213        good    57.0  NaN
# 214         bad    81.0  NaN
# 10000      good    89.0  NaN

# %%
hero['Height']
# Out:
# 0        185
# 1        185
# 2        180
# 3        178
# 4        257
#         ...
# 211      165
# 212      183
# 213      170
# 214      185
# 10000    188
# Name: Height, Length: 216, dtype: int64

# %%
hero['Height']=hero['Height']*0.0328084

# %%
hero['Height']
# Out:
# 0        6.069554
# 1        6.069554
# 2        5.905512
# 3        5.839895
# 4        8.431759
#            ...
# 211      5.413386
# 212      6.003937
# 213      5.577428
# 214      6.069554
# 10000    6.167979
# Name: Height, Length: 216, dtype: float64

# %%
numeric_cols=hero.select_dtypes(include='number').columns

# %%
numeric_cols
# Out:
# Index(['Height', 'Weight'], dtype='object')

# %%
hero[numeric_cols]=hero[numeric_cols]*100

# %%
hero[numeric_cols]
# Out:
#           Height   Weight
# 0      606.95540   9000.0
# 1      606.95540   8800.0
# 2      590.55120   9000.0
# 3      583.98952   7200.0
# 4      843.17588  17300.0
# ...          ...      ...
# 211    541.33860   5100.0
# 212    600.39372   7400.0
# 213    557.74280   5700.0
# 214    606.95540   8100.0
# 10000  616.79792   8900.0
#
# [216 rows x 2 columns]

# %%
hero[numeric_cols]=hero[numeric_cols]/100

# %%
hero[numeric_cols]
# Out:
#          Height  Weight
# 0      6.069554    90.0
# 1      6.069554    88.0
# 2      5.905512    90.0
# 3      5.839895    72.0
# 4      8.431759   173.0
# ...         ...     ...
# 211    5.413386    51.0
# 212    6.003937    74.0
# 213    5.577428    57.0
# 214    6.069554    81.0
# 10000  6.167979    89.0
#
# [216 rows x 2 columns]

# %%
# bmi = weight(kg) / [height(m)]^2
hero['bmi']=hero['Weight']/(hero['Height']/3.28084)**2

# %%
hero.columns
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Alignment', 'Weight', 'race', 'bmi'],
#       dtype='object')

# %%
hero.head(10)
# Out:
#                 name Gender Eye color           Race Hair color    Height
# 0           Abin Sur   Male      blue        Ungaran    No Hair  6.069554  \
# 1       Adam Strange   Male      blue          Human      Blond  6.069554
# 2         Alan Scott   Male      blue        Unknown      Blond  5.905512
# 3  Alfred Pennyworth   Male      blue          Human      Black  5.839895
# 4              Amazo   Male       red        Android          -  8.431759
# 5         Animal Man   Male      blue          Human      Blond  6.003937
# 6       Anti-Monitor   Male    yellow  God / Eternal    No Hair  2.001312
# 7           Aquababy   Male      blue        Unknown      Blond -3.248032
# 8            Aqualad   Male      blue      Atlantean      Black  5.839895
# 9            Aquaman   Male      blue      Atlantean      Blond  6.069554
#
#    Publisher Alignment  Weight     race        bmi
# 0  DC Comics      good    90.0      NaN  26.296567
# 1  DC Comics      good    88.0      NaN  25.712199
# 2  DC Comics      good    90.0  Unknown  27.777778
# 3  DC Comics      good    72.0      NaN  22.724403
# 4  DC Comics       bad   173.0      NaN  26.192675
# 5  DC Comics      good    83.0      NaN  24.784258
# 6  DC Comics       bad     NaN      NaN        NaN
# 7  DC Comics      good     NaN      NaN        NaN
# 8  DC Comics      good   106.0      NaN  33.455372
# 9  DC Comics      good   146.0      NaN  42.658875
