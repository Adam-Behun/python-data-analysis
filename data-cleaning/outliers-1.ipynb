# %%
import pandas as pd
wdi_imp = pd.read_pickle('wdi_imp.pkl')

# %%
wdi_imp.describe()
# Out:
#        access_to_electricity_pct  atms_per_100000  compulsory_education_years
# count                 434.000000       434.000000                  434.000000  \
# mean                   84.215517        46.784191                    9.668580
# std                    24.389620        42.629723                    2.169753
# min                     9.300000         1.213235                    5.000000
# 25%                    70.842500        12.020894                    9.000000
# 50%                    98.912941        38.034455                   10.000000
# 75%                   100.000000        64.213716                   11.000000
# max                   100.000000       272.592801                   16.000000
#
#        health_expenditure_pct_of_gdp  gdp_per_capita_usd  gdp_per_capita_ppp
# count                     434.000000          434.000000          434.000000  \
# mean                        6.446628        13599.891623        19925.226075
# ...
