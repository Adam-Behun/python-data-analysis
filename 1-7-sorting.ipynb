# %%
import pandas as pd

# %%
hero=pd.read_pickle('pickle-data/hero_dc.pkl')
hero.head
# Out:
# <bound method NDFrame.head of                   name  Gender Eye color      Race Hair color  Height
# 0             Abin Sur    Male      blue   Ungaran    No Hair     185  \
# 1         Adam Strange    Male      blue     Human      Blond     185
# 2           Alan Scott    Male      blue         -      Blond     180
# 3    Alfred Pennyworth    Male      blue     Human      Black     178
# 4                Amazo    Male       red   Android          -     257
# ..                 ...     ...       ...       ...        ...     ...
# 210           Wildfire    Male         -         -          -     -99
# 211        Wonder Girl  Female      blue  Demi-God      Blond     165
# 212       Wonder Woman  Female      blue    Amazon      Black     183
# 213            Zatanna  Female      blue     Human      Black     170
# 214               Zoom    Male       red         -      Brown     185
#
#      Publisher Alignment  Weight
# 0    DC Comics      good    90.0
# ...

# %%
hero.sort_values(by='Race', ascending=False)
# Out:
#                name  Gender Eye color        Race Hair color  Height
# 186  Solomon Grundy    Male     black      Zombie      White     279  \
# 0          Abin Sur    Male      blue     Ungaran    No Hair     185
# 191        Starfire  Female     green  Tamaranean     Auburn     193
# 177     Shadow Lass  Female     black    Talokite      Black     173
# 140            Mogo    Male         -      Planet          -     -99
# ..              ...     ...       ...         ...        ...     ...
# 151         Phantom    Male         -           -          -     -99
# 43   Blue Beetle II    Male      blue           -      Brown     183
# 98     Hawkwoman II  Female         -           -          -     -99
# 99    Hawkwoman III  Female      blue           -        Red     170
# 214            Zoom    Male       red           -      Brown     185
#
#      Publisher Alignment  Weight
# 186  DC Comics       bad   437.0
# 0    DC Comics      good    90.0
# 191  DC Comics      good    71.0
# ...

# %%
hero.sort_values(by='Weight', ascending=False).head()
# Out:
#                name  Gender Eye color       Race Hair color  Height
# 64         Darkseid    Male       red    New God    No Hair     267  \
# 86          Giganta  Female     green          -        Red      63
# 186  Solomon Grundy    Male     black     Zombie      White     279
# 70         Doomsday    Male       red      Alien      White     244
# 114     Killer Croc    Male       red  Metahuman    No Hair     244
#
#      Publisher Alignment  Weight
# 64   DC Comics       bad   817.0
# 86   DC Comics       bad   630.0
# 186  DC Comics       bad   437.0
# 70   DC Comics       bad   412.0
# 114  DC Comics       bad   356.0

# %%
hero[['Race','Height']].sort_values(by=['Race','Height'])
# Out:
#            Race  Height
# 7             -     -99
# 13            -     -99
# 16            -     -99
# 17            -     -99
# 19            -     -99
# ..          ...     ...
# 140      Planet     -99
# 177    Talokite     173
# 191  Tamaranean     193
# 0       Ungaran     185
# 186      Zombie     279
#
# [215 rows x 2 columns]

# %%
hero[['Race','Height']].sort_values(by=['Height', 'Race'],ascending=[True, False])
# Out:
#            Race  Height
# 140      Planet     -99
# 149   Parademon     -99
# 84       Mutant     -99
# 76   Kryptonian     -99
# 85   Kryptonian     -99
# ..          ...     ...
# 114   Metahuman     244
# 70        Alien     244
# 4       Android     257
# 64      New God     267
# 186      Zombie     279
#
# [215 rows x 2 columns]

# %%
hero.nlargest(n=10, columns='Height')
# Out:
#                   name Gender Eye color        Race Hair color  Height
# 186     Solomon Grundy   Male     black      Zombie      White     279  \
# 64            Darkseid   Male       red     New God    No Hair     267
# 4                Amazo   Male       red     Android          -     257
# 70            Doomsday   Male       red       Alien      White     244
# 114        Killer Croc   Male       red   Metahuman    No Hair     244
# 116            Kilowog   Male       red  Bolovaxian    No Hair     234
# 124               Lobo   Male       red    Czarnian      Black     229
# 20                Bane   Male         -       Human          -     203
# 127  Martian Manhunter   Male       red     Martian    No Hair     201
# 182           Sinestro   Male     black   Korugaran      Black     201
#
#      Publisher Alignment  Weight
# 186  DC Comics       bad   437.0
# 64   DC Comics       bad   817.0
# 4    DC Comics       bad   173.0
# 70   DC Comics       bad   412.0
# ...

# %%
hero.sort_values(by='Height',ascending=False).head()
# Out:
#                name Gender Eye color       Race Hair color  Height  Publisher
# 186  Solomon Grundy   Male     black     Zombie      White     279  DC Comics  \
# 64         Darkseid   Male       red    New God    No Hair     267  DC Comics
# 4             Amazo   Male       red    Android          -     257  DC Comics
# 114     Killer Croc   Male       red  Metahuman    No Hair     244  DC Comics
# 70         Doomsday   Male       red      Alien      White     244  DC Comics
#
#     Alignment  Weight
# 186       bad   437.0
# 64        bad   817.0
# 4         bad   173.0
# 114       bad   356.0
# 70        bad   412.0

# %%
hero[hero['Height']>0].nsmallest(10, 'Height')
# Out:
#               name  Gender Eye color           Race Hair color  Height
# 6     Anti-Monitor    Male    yellow  God / Eternal    No Hair      61  \
# 86         Giganta  Female     green              -        Red      63
# 118         Krypto    Male      blue     Kryptonian      White      64
# 173        Robin V    Male      blue          Human      Black     137
# 122  Lightning Lad    Male      blue              -        Red     155
# 83        Flash IV    Male    yellow          Human     Auburn     157
# 150        Penguin    Male      blue          Human      Black     157
# 56         Cheetah  Female     green          Human      Blond     163
# 24      Batgirl IV  Female     green          Human      Black     165
# 36    Black Canary  Female      blue          Human      Blond     165
#
#      Publisher Alignment  Weight
# 6    DC Comics       bad     NaN
# 86   DC Comics       bad   630.0
# 118  DC Comics      good    18.0
# 173  DC Comics      good    38.0
# ...
